# %%
#!pip install geobr geopandas

# %%
import geopandas as gpd
import geobr as geobr
import matplotlib.pyplot as plt

# Carregar os dados geográficos dos municípios brasileiros
municipios = geobr.read_municipality()  
#tipo de dado: geodataframe

municipios.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 5567 entries, 0 to 5566
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   code_muni     5567 non-null   float64
#  1   name_muni     5567 non-null   object
#  2   code_state    5567 non-null   float64
#  3   abbrev_state  5567 non-null   object
#  4   geometry      5567 non-null   geometry
# dtypes: float64(2), geometry(1), object(2)
# memory usage: 217.6+ KB

# %%
pbs = geobr.read_municipality(code_muni="PA", year=2024)  

keep = ["name_muni", "code_muni", "name_state", "code_state", "geometry"]
pbs_min = pbs[keep].rename(columns={
    "name_muni": "nm_muni",
    "code_muni": "cd_muni",
    "name_state": "nm_uf",
    "code_state": "cd_uf"
})
#pbs_min.to_file("municipios_PA.shp")

#save as geojson
pbs_min.head()
# Out:
#               nm_muni    cd_muni nm_uf  cd_uf  \
# 0          Abaetetuba  1500107.0  Pará   15.0
# 1     Abel Figueiredo  1500131.0  Pará   15.0
# 2               Acará  1500206.0  Pará   15.0
# 3                Afuá  1500305.0  Pará   15.0
# 4  Água Azul do Norte  1500347.0  Pará   15.0
#
#                                             geometry
# 0  MULTIPOLYGON (((-48.91969 -1.94722, -48.90577 ...
# 1  MULTIPOLYGON (((-48.40107 -4.86873, -48.41237 ...
# 2  MULTIPOLYGON (((-48.14941 -1.77454, -48.15985 ...
# 3  MULTIPOLYGON (((-50.76122 -0.50704, -50.74639 ...
# 4  MULTIPOLYGON (((-50.52625 -7.12643, -50.52572 ...

# %%
pbs.plot()
plt.show()

# %%
pbs2 = geobr.read_municipality(code_muni=1505536)
pbs2.plot()
plt.show()

# %%
pbs2.head()
# Out:
#     code_muni    name_muni  code_state abbrev_state  \
# 88  1505536.0  Parauapebas        15.0           PA
#
#                                              geometry
# 88  POLYGON ((-50.72298 -5.9541, -50.72445 -5.9480...

# %%
df_lookup = geobr.lookup_muni("Parauapebas")

df_lookup.head()
# Out:
#      code_muni    name_muni  code_state name_state abbrev_state  code_micro  \
# 239    1505536  Parauapebas          15      ParÃ¡           PA       15019
#
#       name_micro  code_meso         name_meso  code_immediate name_immediate  \
# 239  Parauapebas       1506  Sudeste Paraense          150010    Parauapebas
#
#      code_intermediate name_intermediate
# 239               1503           MarabÃ¡

# %%
#
